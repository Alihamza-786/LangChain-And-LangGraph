# %%
from tavily import TavilyClient
client = TavilyClient(api_key = "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")

# %%
result = client.search("What is in Nvidia's new Blackwell GPU?",
                       include_answer=True)

result["answer"]
# Out:
# 'The new Blackwell GPU from Nvidia features 208 billion transistors and up to 20 petaflops of FP4 performance. It is designed for AI and claims to be more efficient and cost-effective than previous models.'

# %%
city = "Lahore Pakistan"
query = f"""
what is the current weather in {city}?
Should I travel there today?
"""

# %%
import requests
from bs4 import BeautifulSoup
from duckduckgo_search import DDGS
import re
import time

ddg = DDGS()

def search(query, max_results=3):
    results = ddg.text(query, max_results=max_results)
    time.sleep(5)
    return [i["href"] for i in results]

# %%
for i in search(query):
    print(i)
# Out:
# https://www.accuweather.com/en/pk/lahore/260622/current-weather/260622
# https://www.easeweather.com/asia/pakistan/punjab/lahore-district/lahore/today
# https://weatherin.org/pakistan/punjab/lahore

# %%
def scrape_weather_info(url):
    """Scrape content from the given URL"""
    if not url:
        return "Weather information could not be found."

    #fetch data
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)
    if response.status_code !=200:
        return "Failed to retrieve the webpage."

    #parse result
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %%
# use DuckDuckGo to find a websites and take the first result
url = search(query)[0]

# scrape first website
soup = scrape_weather_info(url)
print(f"Website: {url}\n\n")
print(soup)
# Out:
# Website: https://www.accuweather.com/en/pk/lahore/260622/current-weather/260622
#
#
#
# <!DOCTYPE html>
#
# <html class="accuweather" lang="en-us">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8">
# <link href="https://www.accuweather.com/en/pk/lahore/260622/current-weather/260622" rel="canonical"/>
# <title>Lahore, Punjab, Pakistan Current Weather | AccuWeather</title>
# <meta content="Current weather in Lahore, Punjab, Pakistan. Check current conditions in Lahore, Punjab, Pakistan with radar, hourly, and more." name="Description"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport">
# <meta content="origin" name="referrer"/>
# <meta content="AccuWeather" property="fb:profile_id"/>
# <meta content="132437483467956" property="fb:app_id"/>
# <meta content="71781612888" property="fb:pages"/>
# <meta content="website" property="og:type"/>
# <meta content="Lahore, Punjab, Pakistan Current Weather | AccuWeather" property="og:title"/>
# <meta content="Current weather in Lahore, Punjab, Pakistan. Check current conditions in Lahore, Punjab, Pakistan with radar, hourly, and more." property="og:description"/>
# <meta content="AccuWeather" property="site_name"/>
# <meta content="https://www.accuweather.com/en/pk/lahore/260622/current-weather/260622" property="og:url"/>
# <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" property="og:image"/>
# <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" property="og:image:url"/>
# <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" property="og:image:secure_url"/>
# <meta content="https://twitter.com/accuweather" name="twitter:site"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="Lahore, Punjab, Pakistan Current Weather | AccuWeather" name="twitter:text:title"/>
# <meta content="Lahore, Punjab, Pakistan Current Weather | AccuWeather" name="twitter:title"/>
# <meta content="Current weather in Lahore, Punjab, Pakistan. Check current conditions in Lahore, Punjab, Pakistan with radar, hourly, and more." name="twitter:description"/>
# <meta content="https://twitter.com/accuweather" name="twitter:site:id"/>
# <meta content="https://twitter.com/accuweather" name="twitter:creator"/>
# <meta content="https://twitter.com/accuweather" name="twitter:creator:id"/>
# <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" name="twitter:image"/>
# <meta content="AccuWeather: Weather Tracker" name="twitter:app:name:iphone"/>
# <meta content="U7D6TVQ9TT.com.yourcompany.TestWithCustomTabs" name="twitter:app:id:iphone"/>
# <meta content="https://apps.apple.com/US/app/id300048137?mt=8" name="twitter:app:url:iphone"/>
# <meta content="AccuWeather: Weather Tracker" name="twitter:app:name:ipad"/>
# <meta content="U7D6TVQ9TT.com.yourcompany.TestWithCustomTabs" name="twitter:app:id:ipad"/>
# <meta content="https://apps.apple.com/US/app/id300048137?mt=8" name="twitter:app:url:ipad"/>
# <meta content="AccuWeather Winter weather alerts &amp; forecast radar" name="twitter:app:name:googleplay"/>
# <meta content="com.accuweather.android" name="twitter:app:id:googleplay"/>
# <meta content="https://play.google.com/store/apps/details?id=com.accuweather.android" name="twitter:app:url:googleplay"/>
# <script type="application/ld+json">
# {
# 	"@context": "https://schema.org",
# 	"@type": "Organization",
# 	"name": "AccuWeather",
# 	"url": "https://www.accuweather.com",
# 	"sameAs": [
# 		"https://www.facebook.com/AccuWeather",
# 		"https://twitter.com/BreakingWeather",
# 		"https://www.instagram.com/accuweather",
# 		"https://www.youtube.com/user/accuweather"
#   ]
# }
# </script>
# <script type="application/ld+json">
# 	{
# 		"@context": "https://schema.org",
# 		"@type": "Place",
# 		"address": {
# 			"@type": "PostalAddress",
# 			"addressLocality": "Lahore, Pakistan",
# 			"addressRegion": "Punjab",
# 			"postalCode": ""
# 		},
# 		"geo": {
# 			"@type": "GeoCoordinates",
# 			"latitude": "31.55",
# 			"longitude": "74.327",
# 			"addressCountry": "PK",
# 			"postalCode": ""
# 		},
# 		"name": "Lahore, Punjab, Pakistan"
# 	}
# 	</script>
# <script type="application/ld+json">
# {
# 	"@context": "https://schema.org",
# 	"@type": "WebSite",
# 	"mainEntityOfPage": {
# 		"@type": "WebPage",
# 		"@id": "https://www.accuweather.com/en/pk/lahore/260622/current-weather/260622",
# 		"relatedLink": "https://www.accuweather.com/en/pk/lahore/260622/current-weather/260622"
# 	},
# 	"image": {
# 		"@type": "ImageObject",
# 		"url": "https://www.accuweather.com/images/logos/accuweather-dark.png",
# 		"height": 172,
# 		"width": 1200
# 	},
# 	"author": {
# 		"@type": "Person",
# 		"name": "AccuWeather"
# 	},
# 	"publisher": {
# 		"@context": "https://schema.org",
# 		"@type": "Organization",
# 		"name": "AccuWeather",
# 		"url": "https://www.accuweather.com/",
# 		"logo": {
# 			"@type": "ImageObject",
# 			"url": "https://www.accuweather.com/images/logos/accuweather-dark-small.png",
# 			"width": 163,
# 			"height": 23
# 		}
# 	},
# 	"url": "https://www.accuweather.com/en/pk/lahore/260622/current-weather/260622",
# 	"headline": "Lahore, Punjab, Pakistan Current Weather",
# 	"description": "Current weather in Lahore, Punjab, Pakistan. Check current conditions in Lahore, Punjab, Pakistan with radar, hourly, and more."
# }
# </script>
# <script>window.tagEngineDataLayer = {} ?? {};</script>
# <style>
# 		@font-face {
# 			font-family: 'Solis';
# 			src: url('/fonts/Solis-Regular.woff2') format('woff2');
# 			font-weight: 400;
# 			font-style: normal;
# 			font-display: swap;
# 		}
# 	</style>
# <style>
# 		:root {
# 			--bg: #1f1f1f;
# 			--header-bg: #1f1f1f;
# 			--header-bg-top: #1f1f1f;
# 		}
# 	</style>
# <script>
# 	 var globalAdConfig = {"prebidTimeout":500,"awxTimeout":750,"ortbSite":{"categories":["IAB7","IAB10","IAB15","IAB20","223","274","390","464","653"],"content":{"title":"","url":"","categories":["IAB15-10","390","657"],"productQuality":"1","context":"5","keywords":"","sourceRelationship":1,"language":"","data":{"name":"accuweather.com","extensions":{"segtax":"4"},"segments":[{"name":"id","value":"390"},{"name":"id","value":"657"}]}},"domain":"www.accuweather.com","keywords":"","name":"AccuWeather","privacyPolicy":1,"mobile":1,"pageCategories":["IAB15-10","390","657"],"publisher":{"name":"AccuWeather","domain":"www.accuweather.com","categories":["IAB7","IAB10","IAB15","IAB20","223","274","390","464","653"]},"sectionCategories":[""]},"enableSingleRequest":true,"lazyLoadingData":"{}","skipGoogleAdManager":true,"prebidBundleId":"b","testVariant":"","disableInitialAdLoad":true,"javascriptHead":"","javascriptBody":""};
# 		 (['segtax']).forEach((key) => {if(globalAdConfig.ortbSite.content.data.extensions?.[key]){ globalAdConfig.ortbSite.content.data.extensions[key] = parseInt(globalAdConfig.ortbSite.content.data.extensions[key]) }})
# var isPrebidDisabled = false;
# var adExclusion = null;
# var botDetected = 0;
# var adInfo = {"fdate":"20250617","lang":"en-us","ut":"1","advelvet":"20","bot":"0","pgview":"1","partner":"accuweather","ufdb":"OPLH","city":"Lahore","country":"PK","state":"PB","dma":null,"key":"260622","browser":"other","connection":"_vhigh_5000","wx_seg":"100114108,100114106,100106102,100114107,100113104,100109103,109102102,100114101,100109109,107101102,110101101,101103100,109104102,100114103,101106102,101101104,102104104,101104102,100114102,101102102,105100102,109105101,107100102,101107101,108100102,100114109,104100104,101105100,109100102,104101101,102103100,102101100,102102100,101108100,102100100,108103102,100110103,101100100,100101,100108101,107103104,110100100,109101100,103100102,109103102,108101102,108104104,108102104,103101102,109106102","cuhd":"54","cuhi":"97","cuuv":"8","cuwd":"5","cuwx":"4","realfeel":"100,a100","fc1hi":"94","fc1lo":"80","fc1wx":"5","lfscategory":"warmer","lfsday":"2","lfsseverity":"7","lfs":"7_warmer_2","pt":"0","userid":"active","userid3p":"active","iabctax":"IAB15-10,390,657","sub":""};
#
# // page views
# var awPageViewName = 'awx_pv';
# var pageViewItem = JSON.parse(window.localStorage.getItem(awPageViewName));
# if (!pageViewItem) {
# 	pageViewItem = {val: 1}
# }
# var currentTime = new Date();
# var midnight = new Date();
# var pageViewCount = 1;
# midnight.setDate(midnight.getDate() + 1);
# midnight.setHours(0, 0, 0, 0);
# if (currentTime < pageViewItem.ttl) {
# 	pageViewCount = parseInt(pageViewItem.val ?? 0) + 1;
# }
# window.adInfo = window.adInfo || {};
# window.adInfo.pgview = pageViewCount.toString();
# window.localStorage.setItem(awPageViewName, JSON.stringify({
# 	val: pageViewCount,
# 	ttl: Date.now() + Math.abs(midnight.getTime() - currentTime.getTime())
# }));
#
# var adPageInfo = {category:'weather',template:'current'};
# var partnerCode = 'accuweather';
# var countryCode = 'pk';
# var networkType = 'Unknown';
# var throughput = 'vhigh';
# </script>
# <script>
# 		var serverAdsOnPageLite = {"top":{"config":{"responsiveSizes":[{"window":[1024,0],"sizes":["fluid",[980,120],[980,90],[970,250],[970,90],[950,90],[930,180],[750,100],[750,300],[750,200],[728,90]]},{"window":[768,0],"sizes":["fluid",[728,90],[468,60],[320,50],[300,50]]},{"window":[0,0],"sizes":[[320,100],[320,50],[300,250],[300,100],[300,50],[250,360],[240,400]]}],"bids":[{"bidder":"google","params":{"sizes":"970x250,728x90,fluid","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"appnexus","params":{"placementId":12729470,"allowSmallerSizes":"FALSE","keywords":{"fdate":["20250617"],"advelvet":["20"],"pgview":["1"],"partner":["accuweather"],"ufdb":["OPLH"],"country":["PK"],"state":["PB"],"wx_seg":["100114108","100114106","100106102","100114107","100113104","100109103","109102102","100114101","100109109","107101102","110101101","101103100","109104102","100114103","101106102","101101104","102104104","101104102","100114102","101102102","105100102","109105101","107100102","101107101","108100102","100114109","104100104","101105100","109100102","104101101","102103100","102101100","102102100","101108100","102100100","108103102","100110103","101100100","100101","100108101","107103104","110100100","109101100","103100102","109103102","108101102","108104104","108102104","103101102","109106102"],"cuhd":["54"],"cuhi":["97"],"cuuv":["8"],"cuwd":["5"],"cuwx":["4"],"realfeel":["100","a100"],"fc1hi":["94"],"fc1lo":["80"],"fc1wx":["5"],"lfscategory":["warmer"],"lfsday":["2"],"lfsseverity":["7"],"lfs":["7_warmer_2"],"pt":["0"],"adunit":["/6581/web/asi/top/weather/current"]},"reserve":0.05,"position":"above","supplyType":"web","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"rubicon","params":{"accountId":12562,"siteId":135890,"zoneId":640474,"position":"atf","userId":"5654f41551264d05b9d1490dac4ae117","floor":0.05,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"triplelift","params":{"inventoryCode":"accuweather_d_top_leaderboard_pbjs","floor":0.05,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"pubmatic","params":{"publisherId":"34576","adSlot":"Web_Top","lat":"31.55","lon":"74.33","kadfloor":"0.05","currency":"USD","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"grid","params":{"uid":6028,"keywords":{"fdate":["20250617"],"advelvet":["20"],"pgview":["1"],"partner":["accuweather"],"ufdb":["OPLH"],"country":["PK"],"state":["PB"],"wx_seg":["100114108","100114106","100106102","100114107","100113104","100109103","109102102","100114101","100109109","107101102","110101101","101103100","109104102","100114103","101106102","101101104","102104104","101104102","100114102","101102102","105100102","109105101","107100102","101107101","108100102","100114109","104100104","101105100","109100102","104101101","102103100","102101100","102102100","101108100","102100100","108103102","100110103","101100100","100101","100108101","107103104","110100100","109101100","103100102","109103102","108101102","108104104","108102104","103101102","109106102"],"cuhd":["54"],"cuhi":["97"],"cuuv":["8"],"cuwd":["5"],"cuwx":["4"],"realfeel":["100","a100"],"fc1hi":["94"],"fc1lo":["80"],"fc1wx":["5"],"lfscategory":["warmer"],"lfsday":["2"],"lfsseverity":["7"],"lfs":["7_warmer_2"],"pt":["0"],"adunit":["/6581/web/asi/top/weather/current"]},"bidFloor":0.05,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"yahoossp","params":{"dcn":"8a9691d3017474551cc955a9acbd0027","pos":"web_hb_top_1","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"ix","params":{"siteId":"197759","bidFloor":0.05,"bidFloorCur":"USD","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"openx","params":{"delDomain":"accuweather-d.openx.net","unit":"539580665","customParams":{"fdate":["20250617"],"advelvet":["20"],"pgview":["1"],"partner":["accuweather"],"ufdb":["OPLH"],"country":["PK"],"state":["PB"],"wx_seg":["100114108","100114106","100106102","100114107","100113104","100109103","109102102","100114101","100109109","107101102","110101101","101103100","109104102","100114103","101106102","1 ...
# 		var USPString = '1YNN';
#
# 		try {
# 			;
# 		} catch (error) { }
#
# 		// A map object that stores all ads on page in order where key is the div id and value is the ad object
# 		var pageHasRepeatAds = false;
# 		var adsOnPage = new Map();
# 		const order = ["top","top_right","infeed","bottom_right","middle","native","bottom","oop","interstitial"];
# 		const orderedAds = Object.keys(window.serverAdsOnPageLite)
# 			.sort((a, b) => order.indexOf(a.split('-')[0]) - order.indexOf(b.split('-')[0]))
# 			.filter((adDivId) => order.indexOf(adDivId.split('-')[0]) > -1);
# 		orderedAds.forEach((adId) => {
# 			const adObject = window.serverAdsOnPageLite[adId];
# 			adObject.winner = { auction: 0 };
# 			const strippedId = adId.split('-')[0];
# 			// Mark repeating ad units
# 			if (adsOnPage.has(strippedId)) {
# 				adObject.isRepeat = true;
# 				window.serverAdsOnPageLite[strippedId].isRepeat = true;
# 				window.pageHasRepeatAds = true;
# 			}
# 			adsOnPage.set(adId, adObject)
# 		});
#
# 		// Parse lazy loading config
# 		if (window.globalAdConfig?.lazyLoadingData) {
# 			let lazyLoadData;
# 			try {
# 				lazyLoadData = JSON.parse(window.globalAdConfig.lazyLoadingData.replace(/(['"])?([a-z0-9A-Z_]+)(['"])?:/g, '"$2": '));
# 			} catch (error) { }
# 			if (typeof lazyLoadData === 'object' && Object.keys(lazyLoadData).length > 0) {
# 				window.globalAdConfig.lazyLoadingData = lazyLoadData;
# 			} else {
# 				window.globalAdConfig.lazyLoadingData = null;
# 			}
# 		}
# 		window.adTimeline = [];
# 		window.logAdEvent = (event) => {
# 			window.adTimeline.push([performance.now().toFixed(2), event]);
# 		};
# 		document.addEventListener('DOMContentLoaded',() => {
# 			window.logAdEvent('DOM Ready');
# 		});
# 		function onDomReady(callback) {
# 			if (document.readyState === 'loading') {
# 				document.addEventListener('DOMContentLoaded', callback);
# 			} else {
# 				callback();
# 			}
# 		}
# 	</script>
# <script>
# 	var gaAppConfig = {
#   "snowfallMap": true,
#   "mapCta": true,
#   "iceChart": true,
#   "winterOutlookCard": true,
#   "winterUpcomingCard": true,
#   "impactedCities": true,
#   "tempWindChart": true,
#   "snowfallChart": true,
#   "postEventCta": true,
#   "winterCenterMap": true
# };
# 	var userCookie = {"cDate":"2025-06-17","isDarkMapStyle":false,"lang":"en-us","rl":["260622"],"tp":"C","ccb":true,"userContentAffinity":{}};
# 	var recentLocations = [{"adminArea":{"englishName":"Punjab","id":"PB","localizedName":"Punjab"},"alertCount":0,"country":{"englishName":"Pakistan","id":"PK","localizedName":"Pakistan"},"icon":4,"key":"260622","localizedName":"Lahore","postalCode":"","temp":"32°","realFeel":"39°","isDayTime":true}];
# 	var currentLocation = {"plumeLabsLink":"https://air.plumelabs.com/air-quality-in-lahore-4V0v","englishName":"Lahore","gmtOffset":5.0,"hasAlerts":false,"hasForecastConfidence":true,"hasPollen":false,"hasMinuteCast":true,"hasFutureRadar":true,"lat":31.55,"lon":74.327,"region":{"englishName":"Asia","id":"ASI","localizedName":"Asia"},"timeZone":"PKT","timeZoneCode":"PKT","administrativeArea":{"englishName":"Punjab","id":"PB","localizedName":"Punjab"},"country":{"englishName":"Pakistan","id":"PK","localizedName":"Pakistan"},"key":"260622","localizedName":"Lahore","primaryPostalCode":"","source":"AccuWeather"};
# 	var serverAdsOnPage = [{"config":{"responsiveSizes":[{"window":[1024,0],"sizes":["fluid",[980,120],[980,90],[970,250],[970,90],[950,90],[930,180],[750,100],[750,300],[750,200],[728,90]]},{"window":[768,0],"sizes":["fluid",[728,90],[468,60],[320,50],[300,50]]},{"window":[0,0],"sizes":[[320,100],[320,50],[300,250],[300,100],[300,50],[250,360],[240,400]]}],"bids":[{"bidder":"google","params":{"sizes":"970x250,728x90,fluid","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"appnexus","params":{"placementId":12729470,"allowSmallerSizes":"FALSE","keywords":{"fdate":["20250617"],"advelvet":["20"],"pgview":["1"],"partner":["accuweather"],"ufdb":["OPLH"],"country":["PK"],"state":["PB"],"wx_seg":["100114108","100114106","100106102","100114107","100113104","100109103","109102102","100114101","100109109","107101102","110101101","101103100","109104102","100114103","101106102","101101104","102104104","101104102","100114102","101102102","105100102","109105101","107100102","101107101","108100102","100114109","104100104","101105100","109100102","104101101","102103100","102101100","102102100","101108100","102100100","108103102","100110103","101100100","100101","100108101","107103104","110100100","109101100","103100102","109103102","108101102","108104104","108102104","103101102","109106102"],"cuhd":["54"],"cuhi":["97"],"cuuv":["8"],"cuwd":["5"],"cuwx":["4"],"realfeel":["100","a100"],"fc1hi":["94"],"fc1lo":["80"],"fc1wx":["5"],"lfscategory":["warmer"],"lfsday":["2"],"lfsseverity":["7"],"lfs":["7_warmer_2"],"pt":["0"],"adunit":["/6581/web/asi/top/weather/current"]},"reserve":0.05,"position":"above","supplyType":"web","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"rubicon","params":{"accountId":12562,"siteId":135890,"zoneId":640474,"position":"atf","userId":"5654f41551264d05b9d1490dac4ae117","floor":0.05,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"triplelift","params":{"inventoryCode":"accuweather_d_top_leaderboard_pbjs","floor":0.05,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"pubmatic","params":{"publisherId":"34576","adSlot":"Web_Top","lat":"31.55","lon":"74.33","kadfloor":"0.05","currency":"USD","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"grid","params":{"uid":6028,"keywords":{"fdate":["20250617"],"advelvet":["20"],"pgview":["1"],"partner":["accuweather"],"ufdb":["OPLH"],"country":["PK"],"state":["PB"],"wx_seg":["100114108","100114106","100106102","100114107","100113104","100109103","109102102","100114101","100109109","107101102","110101101","101103100","109104102","100114103","101106102","101101104","102104104","101104102","100114102","101102102","105100102","109105101","107100102","101107101","108100102","100114109","104100104","101105100","109100102","104101101","102103100","102101100","102102100","101108100","102100100","108103102","100110103","101100100","100101","100108101","107103104","110100100","109101100","103100102","109103102","108101102","108104104","108102104","103101102","109106102"],"cuhd":["54"],"cuhi":["97"],"cuuv":["8"],"cuwd":["5"],"cuwx":["4"],"realfeel":["100","a100"],"fc1hi":["94"],"fc1lo":["80"],"fc1wx":["5"],"lfscategory":["warmer"],"lfsday":["2"],"lfsseverity":["7"],"lfs":["7_warmer_2"],"pt":["0"],"adunit":["/6581/web/asi/top/weather/current"]},"bidFloor":0.05,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"yahoossp","params":{"dcn":"8a9691d3017474551cc955a9acbd0027","pos":"web_hb_top_1","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"ix","params":{"siteId":"197759","bidFloor":0.05,"bidFloorCur":"USD","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"openx","params":{"delDomain":"accuweather-d.openx.net","unit":"539580665","customParams":{"fdate":["20250617"],"advelvet":["20"],"pgview":["1"],"partner":["accuweather"],"ufdb":["OPLH"],"country":["PK"],"state":["PB"],"wx_seg":["100114108","100114106","100106102","100114107","100113104","100109103","109102102","100114101","100109109","107101102","110101101","101103100","109104102","100114103","101106102","101101104"," ...
# 	var weatherEvents = [];
# 	var userData = {"city":"LAHORE","continent":1,"countryCode":"PK","county":"","lat":31.57,"lon":74.32,"regionCode":"","throughput":"vhigh","bw":"5000","networkType":"","network":"","zipCodes":[{"primary":""}],"device":{"browserVersion":""}};
# 	var isUserCountryEEA = false;
# 	var maplibre = { style: 'https://accutilerprod.z14.web.core.windows.net/Styles/accu-light-row.json' };
# 	var dts = { token: 'de13920f574d420984d3080b1fa6132b' };
# 	setTimeout(function () {
# 		var reg = new RegExp('(\\s|^)' + 'ads-not-loaded' + '(\\s|$)');
# 		if (document.body.hasAttribute('class')) {
# 			document.body.setAttribute('class', document.body.getAttribute('class').replace(reg, ' '));
# 		}
# 	}, 3000);
# </script>
# <script type="text/javascript">
# 		var PushlySDK = window.PushlySDK || [];
# 		function pushly() { PushlySDK.push(arguments) }
# 		window.pushlyCallback = function() {
# 			pushly('load', {
# 				domainKey: '16if7iQ5tgH1FcRA4cUeejyVcdf5guIAEV9R',
# 				sw: '/pushly-sdk-worker.js'
# 			});
# 		};
# 	</script>
# <script>
# 	function getTDateISOOffset() {
# 		const z = (n) => ('0' + n).slice(-2);
# 		const offset = new Date().getTimezoneOffset();
# 		const hours = Math.floor(Math.abs(offset) / 60);
# 		const minutes = Math.abs(offset) % 60;
# 		const sign = offset > 0 ? '-' : '+';
# 		return `${sign}${z(hours)}:${z(minutes)}`;
# 	}
#
# 	console.log('RaineV1Legacy is active');
#
# 	function createRainePerformanceMark(name) {
# 		if ('performance' in window) {
# 			const markName = `aw:${name}`;
#
# 			// Only fire one timeOnPage mark per session.
# 			if (
# 				name === 'raine:timeOnPage' &&
# 				performance.getEntriesByName(markName).length !== 0
# 			) {
# 				return;
# 			}
#
# 			performance.mark(markName);
# 		}
# 	}
#
# 	function normalizeMarkToTimer(entry, nameParts) {
# 		const timerNameParts = nameParts ?? entry.name.split(':');
# 		return {
# 			name: timerNameParts.slice(1).join(':'),
# 			time: Math.round(entry.startTime),
# 		};
# 	}
#
# 	if ('performance' in window) {
# 		window.pbjs = window.pbjs || {};
# 		pbjs.que = pbjs.que || [];
# 		pbjs.que.push(() => {
# 			pbjs.onEvent('auctionInit', () => {
# 				createRainePerformanceMark('prebid:auctionInit');
# 			});
# 			pbjs.onEvent('auctionEnd', () => {
# 				createRainePerformanceMark('prebid:auctionEnd');
# 			});
# 			pbjs.onEvent('requestBids', () => {
# 				createRainePerformanceMark('prebid:requestBids');
# 			});
# 			pbjs.onEvent('setTargeting', () => {
# 				createRainePerformanceMark('prebid:setTargeting');
# 			});
# 		});
#
# 		window.googletag = window.googletag || { cmd: [] };
#
# 		function truncateAdId(adDivId) {
# 			// /6581/{platform}/{locationId}/{adType}/{category}/{adPageInfo.Template}{suffix}
# 			if (adDivId) {
# 				const arr = adDivId.split('/');
# 				if (arr.length > 1) {
# 					const idIndex = arr.findIndex(x => x === '6581');
# 					adDivId = arr[idIndex + 3];
# 				}
# 			}
# 			return adDivId;
# 		}
#
# 		// ONE-1198 to restrict gpt to 'top' slot only.
# 		function isSupportedAdId(adDivId) {
# 			return ['top'].includes(adDivId);
# 		}
#
# 		googletag.cmd.push(() => {
# 			googletag.pubads().addEventListener('slotRequested', event => {
# 				let adDivId = event.slot.getSlotElementId();
# 				adDivId = truncateAdId(adDivId);
# 				if (isSupportedAdId(adDivId)) {
# 					createRainePerformanceMark(`gpt:slotRequested:${adDivId}`);
# 				}
# 			});
# 			googletag.pubads().addEventListener('slotOnload', event => {
# 				let adDivId = event.slot.getSlotElementId();
# 				adDivId = truncateAdId(adDivId);
# 				if (isSupportedAdId(adDivId)) {
# 					createRainePerformanceMark(`gpt:slotOnload:${adDivId}`);
# 				}
# 			});
# 			googletag.pubads().addEventListener('slotRenderEnded', event => {
# 				let adDivId = event.slot.getSlotElementId();
# 				adDivId = truncateAdId(adDivId);
# 				if (isSupportedAdId(adDivId)) {
# 					createRainePerformanceMark(`gpt:slotRenderEnded:${adDivId}`);
# 				}
# 			});
# 		});
#
# 		window.addEventListener("DOMContentLoaded", (event) => {
# 			createRainePerformanceMark('document:DOMContentLoaded');
# 		});
#
# 		window.addEventListener("load", (event) => {
# 			createRainePerformanceMark('document:windowLoad');
# 		});
# 	}
#
# 	window.raine = {
# 		// Don't use the actual versions here.
# 		pageview: {"test":"raine_variant","version":"2.3.8.1","page":{"group":"current-weather","url":"/en/pk/lahore/260622/current-weather/260622"},"ads":{"code":"/6581/web/asi/top/weather/current","status":"active","cookie3p":"active"},"session":{"id":"b7d2f274-d5d7-4ee5-8807-63448f4420df","utm":{}},"user":{"id":"5654f415-5126-4d05-b9d1-490dac4ae117","language":"en-us","country":"PK","region":"","city":"LAHORE","start":"2025-06-17"},"bot":false,"id":"ffad10db-5a76-46a2-a97e-3a5893cb29b3","platform":"glacier","weather":{"key":"260622"},"device":{"name":"","brand":"","version":"","category":"desktop"},"time":"2025-06-17T07:10:58Z"},
# 	};
#
# 	window.raine.pageview.user.offset = getTDateISOOffset();
#
# 	function tryAddTimer(timers, name) {
# 		if (window[name]) {
# 			timers.push({
# 				name: name,
# 				time: window[name]
# 			});
# 		}
# 	}
#
# 	let scrollDepth = 0;
# 	// Get maximum scroll depth percentage of page every time the user scrolls
# 	window.addEventListener("scroll", function logScrollDepth() {
# 		const currentScrollDepth = Math.round((window.scrollY + window.innerHeight) / document.body.scrollHeight * 100);
# 		scrollDepth = Math.max(scrollDepth, currentScrollDepth);
# 	});
#
# 	function createPageLeave() {
# 		const timers = [];
# 		if ('performance' in window) {
# 			createRainePerformanceMark('raine:timeOnPage');
# 			performance.getEntriesByType('mark').forEach((entry) => {
# 				const timerNameParts = entry.name.split(':');
# 				if (timerNameParts[0] === 'aw' && timerNameParts.length > 2) {
# 					timers.push(normalizeMarkToTimer(entry, timerNameParts));
# 				}
# 			});
# 		}
#
# 		return {
# 			id: window.raine.pageview.id,
# 			time: window.raine.pageview.time,
# 			adblock: window.supportsAds ? false : true,
# 			scroll: scrollDepth,
# 			timers: timers,
# 		};
# 	}
#
# 	window.pageLeave = () => {
# 		window.raine.pageleave = createPageLeave();
# 		return window.raine;
# 	};
#
# 	const headers = {
# 		type: 'application/json',
# 	};
#
# 	let pageleaveFired = false;
# 	function tryFirePageLeave() {
# 		if (!pageleaveFired) {
# 			pageleaveFired = true;
# 			window.raine.pageleave = createPageLeave();
# 			navigator.sendBeacon("https://raine.accuweather.com/rainev1/leavepage", new Blob([JSON.stringify(window.raine.pageleave)], headers));
# 		}
# 	}
#
# 	if (navigator && navigator.sendBeacon) {
# 		navigator.sendBeacon("https://raine.accuweather.com/rainev1/p", new Blob([JSON.stringify(window.raine.pageview)], headers));
# 		document.addEventListener("visibilitychange", function logData() {
# 			if (document.visibilityState === "hidden") {
# 				tryFirePageLeave();
# 			}
# 		});
#
# 		// Send a pageleave beacon after 10 minutes
# 		setTimeout(tryFirePageLeave, 600000);
# 	}
# </script>
# <script>
# 	window.tagEngineDataLayer = {
# 		isSPA: false,
# 		pageGroup: "current-weather",
# 		raine: {
# 			raineV1Host: "https://raine.accuweather.com",
# 			raineV2Host: "https://raine.accuweather.com",
# 			enabledVersions: [],
# 			raineV1: {
# 				pageView: null,
# 			},
# 			raineV2: {
# 				pageView: null,
# 			},
# 		}
# 	};
# </script>
# <script async="" charset="utf-8" src="https://www.awxcdn.com/adc-assets/bundles/prebid-b.02f05624d87c4dcef1e5.js"></script>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script async="true" charset="utf-8" src="//b-code.liadm.com/b-020q.min.js" type="text/javascript"></script>
# <script>
# 		window.googletag = window.googletag || { cmd: [] };
# 		window.pbjs = window.pbjs || {};
# 		pbjs.que = pbjs.que || [];
# 		// Initialize ad info
# 		adInfo['hour'] = new Date().getHours().toString();
# 		const width = document.documentElement.clientWidth;
# 		const height = document.documentElement.clientHeight;
# 		const round = x => Math.ceil(x / 10) * 10;
# 		adInfo['viewport'] = `${round(width)}x${round(height)}`;
# 		adInfo['site'] = width >= 768
# 			? (width >= 1024 ? 'desktop' : 'tablet')
# 			: 'mobile';
# 		// Helper function for uprTargeting
# 		window.uprTargeting = (gptSlot, adObject) => {
#
# 						const highestPrebid = pbjs?.getHighestCpmBids ? pbjs.getHighestCpmBids(adObject.adUnitCode) : [];
# 						const prebidCPM = highestPrebid.length ? highestPrebid[0].cpm || 0 : 0;
# 											const round = (n) => {
# 												if (n > 15) {
# 													return '15.00';
# 												} else if (n > 10) {
# 													return String(Math.round(n).toFixed(2));
# 												} else {
# 													// Round to closest half
# 													return String((Math.round(n * 2) / 2).toFixed(2));
# 												}
# 											};
# 						const upr_0 = prebidCPM ? round(prebidCPM) : 'no_bid';
# 						let hb_bid_1st = 'no_bid';
# 						let hb_bid_2nd = 'no_bid';
# 						if (pbjs?.getBidResponsesForAdUnitCode) {
# 												const formatCpm = (cpm) => (Math.round(cpm * 10) / 10).toFixed(2);
# 						const bidResponses = pbjs.getBidResponsesForAdUnitCode(adObject.adUnitCode).bids;
# 												bidResponses.sort((a, b) => b.cpm - a.cpm);
# 						if (bidResponses[0]) {
# 							hb_bid_1st = formatCpm(bidResponses[0].cpm);
# 												}
# 						if (bidResponses[1]) {
# 							hb_bid_2nd = formatCpm(bidResponses[1].cpm);
# 												}
# 											}
# 						const uprTargeting = {
# 							upr: adObject.upr,
# 						upr_0,
# 						upr_auction: 'prebid',
# 						userid3pbid: `${window.adInfo['userid3p']}-${upr_0}`,
# 						hb_bid_1st,
# 						hb_bid_2nd,
# 											};
# 								if (gptSlot) {
# 				Object.keys(uprTargeting).forEach((key) => {
# 					if (uprTargeting[key]) {
# 						gptSlot.setTargeting(key, String(uprTargeting[key]));
# 					}
# 				});
# 			}
# 			return uprTargeting;
# 		};
#
# 		// Setup Gamera
# 		if (window.userData.countryCode.toLowerCase() === 'us') {
# 			// this is temporary to ensure a seamless transtion from ad server to page. I'll look for this value in the ad server code and if true, not load the ad server code.
# 			window.gameraFromPage = true;
#
# 			let aw_page = '', aw_gam_code = '', aw_partner = '', aw_wx_seg = '';
# 			let ltv = 1;
#
# 			try {
# 				if (window.serverAdsOnPageLite) {
# 					aw_gam_code = Object.values(window.serverAdsOnPageLite)[0].adUnitCode;
# 				}
#
# 				aw_page = window.RaineV2?.pageView?.pageInfo?.group || '';
# 				aw_partner = window?.adInfo?.partner || 'accuweather';
# 				aw_wx_seg = window?.adInfo?.wx_seg || '';
# 				ltv = window.adInfo?.rdp === '1' ? 0 : 1;
# 			} catch (e) { }
#
# 			window.gamera = window.gamera || {};
# 			window.gamera.cmd = window.gamera.cmd || [];
# 			window.gamera.cmd.push(function () {
# 				//custom dimensions
# 				window.gamera.addDimensions({
# 					"aw_site": aw_gam_code.split('/')[2],
# 					"aw_wxGeo": aw_gam_code.split('/')[3],
# 					"aw_page": aw_page.replace('/', ''),
# 					"aw_partner": aw_partner,
# 					"aw_wx_seg": aw_wx_seg
# 				});
#
# 				//set 3 new key-values in the adInfo object from Gamera on-page data to be passed as page-level key-value pairs
# 				try {
# 					let ucpm = window?.gamera?.getOnPageSegments()?.filter((cpm) => /^user_cpm/.test(cpm)).join(",") || undefined;
# 					if (ucpm) {
# 						ucpm = (Math.round(parseFloat(ucpm.split("_").pop()) * 20) / 20).toFixed(2);
# 						window.adInfo.ucpm = ucpm;
# 					}
# 				} catch (e) { }
#
# 				try {
# 					window.adInfo.cohort = window?.gamera?.getOnPageSegments()?.filter((cpm) => !/^user_cpm/.test(cpm)).join(",") || window.adInfo.cohort || undefined;
# 					window.adInfo.iabatax = window?.gamera?.getPrebidSegments()?.user?.data[0]?.segment?.map(a => a.id).join(',') || window.adInfo.iabatax || undefined;
# 				} catch (e) { }
# 			});
#
# 			//add the Gamera tag
# 			const s = document.createElement("script");
# 			const el = document.getElementsByTagName("script")[0];
# 			s.setAttribute('id', '__gamera__');
# 			s.setAttribute('async', 'true');
# 			s.src = `https://metrics.rapidedge.io/gamera.js?domain=accuweather.com&ltv=${ltv}&tpcs=1`;
# 			el.parentNode.insertBefore(s, el);
# 		}
#
# 		// Configure LiveIntent
# 		const TREATMENT_RATE = 0.90;
# 		if (window.liModuleEnabled === undefined) {
# 			// To manage the control group selection externally, override the
# 			// true = treated group, false = control group.
# 			window.liModuleEnabled = Math.random() < TREATMENT_RATE;
# 			window.liTreatmentRate = TREATMENT_RATE;
# 		}
# 	</script>
# <script>
# 		const fixedLengthNumber = (number, decimals) => {
# 			if (number == null) return number;
#
# 			const factor = Math.pow(10, decimals);
# 			let roundedNumber = Math.round(number * factor) / factor;
# 			const smallestIncrement = 1 / factor;
#
# 			if (roundedNumber === number) {
# 				if (number >= 0) {
# 					roundedNumber += smallestIncrement;
# 				} else {
# 					roundedNumber -= smallestIncrement;
# 				}
# 			}
#
# 			return parseFloat(roundedNumber.toFixed(decimals));
# 		}
#
# 		window.BIDDING_TIMEOUT = (window.globalAdConfig && typeof window.globalAdConfig.prebidTimeout === 'number') ? window.globalAdConfig.prebidTimeout : 750;
# 		// Initialize prebid
# 		pbjs.que.push(() => {
# 			window.logAdEvent('Prebid: Init');
# 			// Record prebid loaded event
#
# 			// Pbjs config
# 			const weatherLocData = window.currentLocation;
# 			let ortb2Geo = {};
# 			if (weatherLocData?.country?.id === 'US') {
# 				ortb2Geo = {
# 					country: 'usa',
# 					region: weatherLocData.administrativeArea?.id,
# 					metro: weatherLocData.dma?.id,
# 					city: weatherLocData.englishName,
# 					zip: weatherLocData.primaryPostalCode,
# 					utcoffset: weatherLocData.gmtOffset * 60,
# 					type: 3,
# 					lat: fixedLengthNumber(weatherLocData.lat, 4),
# 					lon: fixedLengthNumber(weatherLocData.lon, 4),
# 				};
# 			}
# 			const ortb2User = { data: {} };
# 			(['userid', 'userid3p', 'partner', 'pgview', 'pt', 'viewport', 'hour']).forEach((key) => {
# 				if (window.adInfo && window.adInfo[key]) {
# 					ortb2User.data[key] = window.adInfo[key].replaceAll('-', 'neg');
# 				}
# 			});
# 			const ortbSiteConfig = window.globalAdConfig?.ortbSite;
# 			let ortb2Site = {
# 				name: 'AccuWeather',
# 				domain: 'www.accuweather.com',
# 				cat: ['IAB-7', 'IAB7-4', 'IAB15-10', 'IAB20', '288', '390', '653'],
# 				page: `${window.location.protocol}//${window.location.host}${window.location.pathname}`,
# 				ref: document.referrer,
# 				mobile: 1,
# 				privacypolicy: 1,
# 				publisher: {
# 					name: 'AccuWeather',
# 					domain: 'www.accuweather.com',
# 					cat: ['IAB-7', 'IAB7-4', 'IAB15-10', 'IAB20', '288', '390', '653'],
# 				},
# 				content: {
# 					language: window.userCookie?.lang?.substring(0, 2),
# 				},
# 				ext: {
# 					data: {},
# 				},
# 			};
# 			if (ortbSiteConfig) {
# 				ortb2Site = {
# 					name: ortbSiteConfig.name,
# 					domain: ortbSiteConfig.domain,
# 					cat: ortbSiteConfig.categories,
# 					page: `${window.location.protocol}//${window.location.host}${window.location.pathname}`,
# 					ref: document.referrer,
# 					mobile: ortbSiteConfig.mobile,
# 					privacypolicy: ortbSiteConfig.privacyPolicy,
# 					publisher: {
# 						name: ortbSiteConfig.publisher.name,
# 						domain: ortbSiteConfig.publisher.domain,
# 						cat: ortbSiteConfig.publisher.categories,
# 					},
# 					content: {
# 						language: window.userCookie?.lang?.substring(0, 2),
# 						title: document.title,
# 						keywords: ortbSiteConfig.content.keywords,
# 						url: `${window.location.protocol}//${window.location.host}${window.location.pathname}`,
# 						cat: ortbSiteConfig.content.categories,
# 						prodq: parseInt(ortbSiteConfig.content.productQuality),
# 						context: parseInt(ortbSiteConfig.content.context),
# 						sourcerelationship: ortbSiteConfig.content.sourceRelationship,
# 						data: [{
# 							name: ortbSiteConfig.content.data.name,
# 							ext: ortbSiteConfig.content.data.extensions,
# 							segment: ortbSiteConfig.content.data.segments
# 						}]
# 					},
# 					sectioncat: ortbSiteConfig.sectionCategories,
# 					pagecat: ortbSiteConfig.pageCategories,
# 					keywords: ortbSiteConfig.keywords,
# 					ext: {
# 						data: {},
# 					},
# 				};
# 			}
# 			(['advelvet', 'country', 'cuhd', 'cuhi', 'cuuv', 'cuwd', 'cuwx',
# 				'dma', 'fdate', 'state', 'wx_seg', 'ufdb', 'alertscategory', 'alertssource',
# 				'alertstypeid', 'site', 'realfeel']).forEach((key) => {
# 					if (window.adInfo && window.adInfo[key]) {
# 						ortb2Site.ext.data[key] = window.adInfo[key].replaceAll('-', 'neg').split(',');
# 					}
# 				});
# 			// Add ortb2.site.ext.data.bin_top and ortb2.site.ext.data.upr_top
# 			if (window.serverAdsOnPageLite?.top) {
# 				const { upr, config } = window.serverAdsOnPageLite.top;
# 				const binTop = config.bids.find(bid => (bid.bidder === 'rubicon' && bid.isBuyItNow));
# 				ortb2Site.ext.data.bin_top = binTop?.params?.floor;
# 				ortb2Site.ext.data.upr_top = upr;
# 			}
#
# 						const userSync = {
# 							filterSettings: {
# 							iframe: {
# 							bidders: '*',
# 						filter: 'include',
# 														},
# 													},
# 						syncsPerBidder: 0,
# 						aliasSyncEnabled: true,
# 						syncDelay: 6000,
# 						userIds: [
# 						{
# 							name: 'sharedId',
# 						storage: {
# 							type: 'cookie',
# 						name: '_pubcid', // create a cookie with this name
# 						expires: 30, // expires in 1 month
# 															},
# 														},
# 						{
# 							name: 'criteo',
# 														},
# 						{
# 							name: 'pubProvidedId',
# 						params: {
# 							eids: [
# 						{
# 							source: "accuweather.com",
# 						uids: [
# 						{
# 							id: '5654f41551264d05b9d1490dac4ae117',
# 						atype: 1,
# 						ext: {stype: "ppuid"}
# 																			},
# 						],
# 																	}
# 						]
# 															}
# 														},
# 						{
# 							name: "33acrossId",
# 						params: {
# 							pid: "0014000000xvF2DAAU"
# 															},
# 						storage: {
# 							name: "33acrossId",
# 						type: "html5",
# 						expires: 90,
# 						refreshInSeconds: 8 * 3600
# 															}
# 														},
# 						{
# 							name: 'unifiedId',
# 						params: {
# 							partner: 'vtlti0n'
# 															},
# 														},
# 						{
# 							name: "connectId",
# 						params: {
# 							pixelId: '58872',
# 						puid: '5654f41551264d05b9d1490dac4ae117',
# 															}
# 														},
# 						],
# 												};
# 								const config = {
# 				bidderTimeout: window.BIDDING_TIMEOUT,
# 				enableSendAllBids: false,
# 				disableAjaxTimeout: true,
# 				maxRequestsPerOrigin: 6,
# 				enableTIDs: true,
# 				bidderSequence: 'fixed',
# 				priceGranularity: {
# 					buckets: [
# 						{
# 							precision: 2,
# 							max: 3,
# 							increment: 0.01,
# 						},
# 						{
# 							precision: 2,
# 							max: 8,
# 							increment: 0.05,
# 						},
# 						{
# 							precision: 2,
# 							max: 20,
# 							increment: 0.5,
# 						},
# 						{
# 							precision: 2,
# 							max: 100,
# 							increment: 1,
# 						},
# 					],
# 				},
# 				userSync: userSync,
# 				deviceAccess: true,
# 				cache: {
# 					url: 'https://prebid.adnxs.com/pbc/v1/cache',
# 				},
# 				rubicon: {
# 					singleRequest: true,
# 				},
# 				yahoossp: {
# 					endpoint: 'https://c2shb.ssp.yahoo.com/bidRequest',
# 					singleRequestMode: true
# 				},
# 				useBidCache: true,
# 				bidCacheFilterFunction: bid => bid.mediaType !== 'video',
# 				timeoutBuffer: 0,
# 				ortb2: {
# 					site: ortb2Site,
# 					user: {
# 						ext: ortb2User,
# 						geo: ortb2Geo,
# 					},
# 				},
# 				realTimeData: {
# 					dataProviders: [{
# 						name: 'gamera',
# 						params: {},
# 						waitForIt: true,
# 					}]
# 				}
# 			};
#
# 			if (window.userData) {
# 				config.ortb2.device = { geo: { type: 2 } };
# 				if (window.userData.lat) {
# 					config.ortb2.device.geo.lat = fixedLengthNumber(window.userData.lat, 4);
# 				}
# 				if (window.userData.lon) {
# 					config.ortb2.device.geo.lon = fixedLengthNumber(window.userData.lon, 4);
# 				}
# 				if (window.userData.city) {
# 					config.ortb2.device.geo.city = window.userData.city;
# 				}
# 				if (window.userData.countryCode) {
# 					config.ortb2.device.geo.country = window.userData.countryCode;
# 				}
# 				if (window.userData.dma) {
# 					config.ortb2.device.geo.metro = window.userData.dma;
# 				}
# 				if (window.userData.regionCode) {
# 					config.ortb2.device.geo.region = window.userData.regionCode;
# 				}
# 				if (Array.isArray(window.userData.zipCodes) && window.userData.zipCodes.length) {
# 					config.ortb2.device.geo.zip = window.userData.zipCodes[0]?.primary;
# 				}
# 			}
#
# 			if (window.userData?.countryCode?.toLowerCase() === 'us') {
# 				config.consentManagement = {
# 					usp: {
# 						cmpApi: 'iab'
# 					},
# 				};
# 			} else if (window.isUserCountryEEA) {
# 				config.consentManagement = {
# 					gdpr: {
# 						cmpApi: 'iab',
# 					},
# 				};
# 			}
#
#
# 				pbjs.setConfig(config);
# 			pbjs.bidderSettings = {
# 				standard: {
# 					storageAllowed: true,
# 				}
# 			};
#
# 			const LI_REPORTING_KEY = 'li-module-enabled';
# 			const setTargeting = (enriched) => {
# 				window.googletag.cmd.push(() => {
# 					let targeting = window.liModuleEnabled ? 't1' : 't0';
# 					if (enriched !== undefined) {
# 						targeting += enriched ? '-e1' : '-e0';
# 					}
# 					window.googletag.pubads().setTargeting(LI_REPORTING_KEY, targeting);
# 				});
# 			}
# 			setTargeting();
#
# 			// Enable the module, only if the visit is in the treated group
# 			const LI_PUBLISHER_ID = 90448;
# 			if (window.liModuleEnabled) {
# 				pbjs.mergeConfig({
# 					userSync: {
# 						auctionDelay: 300,
# 						userIds: [
# 							{
# 								name: "liveIntentId",
# 								bidders: ['rubicon', 'pubmatic', 'ix', 'ttd', 'grid', 'openx'],
# 								params: {
# 									publisherId: LI_PUBLISHER_ID,
# 									requestedAttributesOverrides: {
# 										uid2: true,
# 										bidswitch: true,
# 										medianet: true,
# 										magnite: true,
# 										pubmatic: true,
# 										index: true,
# 										openx: true,
# 										thetradedesk: true,
# 										sovrn: true
# 									},
# 								},
# 								storage: {
# 									type: "html5",
# 									name: "__tamLIResolveResult",
# 									expires: 1,
# 								},
# 							},
# 						],
# 					},
# 				});
# 				pbjs.refreshUserIds({ submoduleNames: ["liveIntentId"] });
# 			}
#
# 			const auctionsEnriched = {};
# 			pbjs.onEvent("auctionInit", (args) => {
# 				auctionsEnriched[args.auctionId] =
# 					args.adUnits &&
# 					args.adUnits.some(
# 						(au) =>
# 							au.bids &&
# 							au.bids.some(
# 								(b) =>
# 									b.userIdAsEids &&
# 									b.userIdAsEids.some(
# 										(eid) =>
# 											eid.source === "liveintent.com" ||
# 											(eid.uids &&
# 												eid.uids.some(
# 													(uid) =>
# 														uid.ext && uid.ext.provider === "liveintent.com"
# 												))
# 									)
# 							)
# 					);
# 				setTargeting(auctionsEnriched[args.auctionId]);
# 			});
#
# 			if (window.localStorage?.OPTABLE_RESOLVED) {
# 				try {
# 					const eids = JSON.parse(window.localStorage.OPTABLE_RESOLVED).ortb2.user.eids;
# 					pbjs.mergeConfig({ userSync: { userIds: [{ name: "pubProvidedId", params: { eids } }] } });
# 					pbjs.refreshUserIds({ submoduleNames: ['pubProvidedId'] });
#
# 					// add page level tageting to googletag if eids exist to measure uplift
# 					if (eids) {
# 						if (window.adInfo.campaign) {
# 							window.adInfo.campaign += ",optable";
# 						} else {
# 							window.adInfo.campaign = "optable";
# 						}
# 					}
# 				} catch (error) { }
# 			}
#
# 			// Create and push pbjs ad units
# 			const ALLOWED_SIZES = {
# 				top: ['300x250', '320x50', '300x50', '336x280', '728x90', '970x250', '970x90'],
# 				top_right: ['300x250', '300x600', '160x600'],
# 				bottom_right: ['300x250', '300x600', '160x600'],
# 				bottom: ['300x250', '320x50', '300x50', '300x600', '336x280', '728x90', '970x250', '970x90'],
# 				adhesion: ['320x50', '300x50'],
# 				middle: ['300x250', '320x50', '300x50', '300x600', '336x280'],
# 				native: ['1x1', '2x2', '300x250'],
# 				infeed: ['1x1', '2x2'],
# 			};
# 			(Object.keys(window.serverAdsOnPageLite) || []).forEach((key) => {
# 				const { adUnitCode, adType, config = {} } = window.serverAdsOnPageLite[key];
# 				let { responsiveSizes = [], bids = [], sizes = [] } = config;
# 				// Only add pbjs ad unit if we have bids for the ad slot
# 				if (bids.length) {
# 					// If responsiveSizes are defined, use it for sizes
# 					responsiveSizes.forEach(respSize => {
# 						if (sizes.length === 0 && document.documentElement.clientWidth >= respSize.window[0]) {
# 							sizes = respSize.sizes;
# 						}
# 					});
# 					const filteredSizes = sizes.filter((size) => {
# 						const allowedSizes = ALLOWED_SIZES[adType] || [];
# 						return Array.isArray(size) && allowedSizes.indexOf(size.join('x')) > -1;
# 					});
#
# 					// ONE-279: Remove buy it now bids when initial ad load is not disabled
# 					if (window.globalAdConfig && !window.globalAdConfig.disableInitialAdLoad) {
# 						bids = bids.filter((bid) => !bid.isBuyItNow);
# 					}
#
# 					const userData = window.userData;
# 					if (userData?.countryCode?.toLowerCase() !== 'us') {
# 						bids = bids.filter((bid) => bid.bidder !== 'yahoossp');
# 					}
#
#
# 					const mediaTypes = {
# 						banner: {
# 							sizes: filteredSizes,
# 						},
# 					};
# 					if (adType === 'native' || adType === 'infeed') {
# 						mediaTypes.native = {
# 							type: 'image',
# 						};
# 					}
# 					pbjs.addAdUnits({
# 						bids: bids.filter(b => !b.isBuyItNow),
# 						mediaTypes,
# 						code: adUnitCode,
# 						ortb2Imp: { ext: { data: { pbadslot: adUnitCode }, gpid: adUnitCode } },
# 					});
#
# 					const hasBuyItNow = bids.some(b => b.isBuyItNow);
#
# 					if (hasBuyItNow) {
# 						pbjs.addAdUnits({
# 							bids: bids.filter(b => b.isBuyItNow),
# 							mediaTypes,
# 							code: adUnitCode,
# 							ortb2Imp: { ext: { data: { pbadslot: adUnitCode + '-bin' }, gpid: adUnitCode + '-bin' } }
# 						});
# 					}
# 				}
# 			});
# 		});
# 		// Prebid fetch promise
# 		const fetchPrebidBids = (adUnitCodes = []) => {
# 			let IS_BID_REQUESTED = false;
# 			return new Promise((resolve) => {
# 				const requestBids = () => {
# 					if (IS_BID_REQUESTED) {
# 						return resolve();
# 					}
# 					IS_BID_REQUESTED = true;
# 					try {
# 						window.logAdEvent('Prebid: Request Bids Start');
# 						pbjs.requestBids({
# 							adUnitCodes,
# 							timeout: window.BIDDING_TIMEOUT,
# 							bidsBackHandler: (prebidBids) => {
# 								window.logAdEvent('Prebid: Request Bids Complete');
# 								resolve(prebidBids);
# 							},
# 						});
# 					} catch (error) {
# 						console.warn('Ad manager: error pbjs.requestBids', error);
# 						resolve();
# 					}
# 				};
# 				pbjs.que.push(requestBids);
# 			});
# 		};
# 		window.renderPrebidWithIframe = (adObject, bid) => {
# 			const adDivEl = document.getElementById(adObject.adDivId);
# 			adDivEl.innerHTML = '';
# 			const isNotForSafeFrame = bid.width <= 2 || bid.height <= 2;
#
# 			const iframe = document.createElement('iframe');
#
# 			if (!isNotForSafeFrame) {
# 				iframe.setAttribute(
# 					'src',
# 					'https://www.awxcdn.com/safeframe/1-0-0/html/container.html'
# 				);
# 				iframe.setAttribute('name', bid.adId);
# 				iframe.setAttribute(
# 					'sandbox',
# 					'allow-forms allow-pointer-lock allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation'
# 				);
# 				iframe.setAttribute('height', bid.height);
# 				iframe.setAttribute('width', bid.width);
# 			}
# 			iframe.setAttribute('style', 'display:block;margin:auto');
# 			iframe.setAttribute('frameborder', 0);
# 			iframe.setAttribute('scrolling', 'no');
# 			iframe.setAttribute('marginheight', 0);
# 			iframe.setAttribute('marginwidth', 0);
# 			iframe.setAttribute('TOPMARGIN', 0);
# 			iframe.setAttribute('LEFTMARGIN', 0);
# 			iframe.setAttribute('allowtransparency', 'true');
# 			adDivEl.appendChild(iframe);
# 			if (isNotForSafeFrame) {
# 				pbjs.renderAd(iframe.contentWindow.document, bid.adId);
# 			}
# 		};
# 	</script>
# <script>
#
# 											window.prebidTimeoutPromise = new Promise((resolve) => {
# 						pbjs.que.push(() => {
# 							pbjs.onEvent('auctionInit', () => {
# 								setTimeout(resolve, window.BIDDING_TIMEOUT);
# 							});
# 						});
# 											});
# 					const buyItNowBids = [];
# 											pbjs.que.push(() => {
# 						pbjs.onEvent('auctionInit', (auction) => {
# 							auction.bidderRequests.forEach((bidder) => {
# 								bidder.bids.forEach((bid) => {
# 									if (bid.isBuyItNow) {
# 										buyItNowBids.push(bid.bidId);
# 									}
# 								});
# 							});
# 						});
# 											});
# 					// If GPT lazy load is enabled and page has repeating ad units, only run auction for slots before second repeating unit
# 					let adUnitCodesToFetch = [];
# 					window.initialAdDivIdsAuction = [];
# 					if (window.globalAdConfig?.lazyLoadingData && window.pageHasRepeatAds) {
# 												for (const [adId, adObject] of adsOnPage.entries()) {
# 						adUnitCodesToFetch.push(adObject.adUnitCode);
# 					window.initialAdDivIdsAuction.push(adObject.adDivId);
# 					if (adObject.isRepeat) {
# 														break;
# 													}
# 												}
# 											}
# 					window.prebidBidPromise = fetchPrebidBids(adUnitCodesToFetch);
# 						// Ad results object
# 		const prevAdResults = JSON.parse(localStorage.getItem('adResults'));
# ...
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/twitter.svg" height="32" viewbox="0 0 36 36" width="32"><g fill="none" fill-rule="nonzero"><path d="M18 0C8.053 0 0 8.053 0 18s8.053 18 18 18 18-8.053 18-18S27.947 0 18 0Z" fill="#1DA1F3"></path><path d="M26.904 14.316c.012.183.012.376.012.57 0 5.774-4.294 12.448-12.14 12.448a11.96 11.96 0 0 1-6.538-1.96c.33.046.672.058 1.014.058a8.424 8.424 0 0 0 5.296-1.868c-1.868-.034-3.44-1.298-3.987-3.04.262.056.524.079.798.079.387 0 .763-.057 1.127-.16-1.947-.398-3.428-2.163-3.428-4.293v-.057c.581.33 1.23.524 1.936.547a4.417 4.417 0 0 1-1.902-3.645c0-.797.205-1.549.581-2.198 2.107 2.654 5.25 4.385 8.792 4.567a4.717 4.717 0 0 1-.114-.99c0-2.415 1.914-4.374 4.26-4.374 1.23 0 2.335.535 3.109 1.378a8.26 8.26 0 0 0 2.71-1.06 4.3 4.3 0 0 1-1.879 2.415A8.4 8.4 0 0 0 29 12.05c-.535.877-1.264 1.64-2.096 2.266Z" fill="#FFF"></path></g></svg>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </span>
# <div class="footer-legalese">
# <div class="footer-copyright">
# <span>
# 			© 2025 AccuWeather, Inc. "AccuWeather" and sun design are registered trademarks of AccuWeather, Inc. All Rights Reserved.
#
# 		</span>
# </div>
# <div class="footer-terms" id="footer-terms">
# <a data-ga="Terms of Use" href="/en/legal" target="_blank">
# 			Terms of Use
# 		</a>
# 		|
# 		<a data-ga="Privacy Policy" href="/en/privacy" target="_blank">
# 			Privacy Policy
# 		</a>
# 		|
# 		<a data-ga="Cookie Policy" href="/en/cookiepolicy" target="_blank">
# 			Cookie Policy
# 		</a>
# </div>
# </div>
# </div>
# </div>
# <script>
# 		// Check for third party cookie support
# 		const thirdPartyIframe = document.createElement('iframe');
# 		thirdPartyIframe.setAttribute(
# 			'src',
# 			'https://www.awxcdn.com/adc/3rdpartycheck.html'
# 		);
# 		thirdPartyIframe.setAttribute('style', 'width:0;height:0;display:none');
# 		document.body.appendChild(thirdPartyIframe);
# 	</script>
# <script async="" charset="utf-8" src="https://www.awxcdn.com/adc-assets/bundles/city.current-weather-desktop.031d19d0c3879e05f820.js"></script>
# <script async="" charset="utf-8" src="https://www.awxcdn.com/adc-assets/bundles/2531.ea95b6481508d6fe5f74.js"></script>
# <script async="" charset="utf-8" src="https://www.awxcdn.com/adc-assets/bundles/6850.535f28700c34a938969f.js"></script>
# <script async="" charset="utf-8" src="https://www.awxcdn.com/adc-assets/bundles/legacy-header.ac9eff85c09ee9d1ce8d.js"></script>
# <script>
# 		window.tagEngineDataLayer = window.tagEngineDataLayer || {};
# 		window.tagEngineDataLayer.connatix = {"isActive":true,"adUnitCode":"/6581/web/asi/video_player/weather/current","adInfo":{"fdate":"20250617","lang":"en-us","ut":"1","advelvet":"20","bot":"0","pgview":"1","partner":"accuweather","ufdb":"OPLH","city":"Lahore","country":"PK","state":"PB","dma":null,"key":"260622","browser":"other","connection":"_vhigh_5000","wx_seg":"100114108,100114106,100106102,100114107,100113104,100109103,109102102,100114101,100109109,107101102,110101101,101103100,109104102,100114103,101106102,101101104,102104104,101104102,100114102,101102102,105100102,109105101,107100102,101107101,108100102,100114109,104100104,101105100,109100102,104101101,102103100,102101100,102102100,101108100,102100100,108103102,100110103,101100100,100101,100108101,107103104,110100100,109101100,103100102,109103102,108101102,108104104,108102104,103101102,109106102","cuhd":"54","cuhi":"97","cuuv":"8","cuwd":"5","cuwx":"4","realfeel":"100,a100","fc1hi":"94","fc1lo":"80","fc1wx":"5","lfscategory":"warmer","lfsday":"2","lfsseverity":"7","lfs":"7_warmer_2","pt":"0","userid":"active","userid3p":"active","iabctax":"IAB15-10,390,657","sub":""},"ppid":"5654f41551264d05b9d1490dac4ae117","thirdPartyCookie":"active","cacheBuster":638857410580563720,"gdprConsent":null};
# 	</script>
# <script>
#         window.tagEngineDataLayer = window.tagEngineDataLayer || {};
#         window.tagEngineDataLayer.comScore = {
#             cs_fpid: "5654f415-5126-4d05-b9d1-490dac4ae117",
#             c4: "https://www.accuweather.com/en/pk/lahore/260622/current-weather/260622",
#             c7: "https://www.accuweather.com/en/pk/lahore/260622/current-weather/260622",
#             c8: "Lahore, Punjab, Pakistan Current Weather | AccuWeather",
#             c9: ""
#         };
#     </script>
# <script>
# 	var isPushlyEnabled = true;
# </script>
# <script>
# 		window.tagEngineDataLayer = window.tagEngineDataLayer || {};
# 		window.tagEngineDataLayer.pushly = {
# 			isEnabled: true,
# 			pushlyKey: "16if7iQ5tgH1FcRA4cUeejyVcdf5guIAEV9R",
# 			userLocationKeys: ["260622"]
# 		};
# 	</script>
# <script>
# 		function callBlockthroughScript() {
# 			const scriptEl = document.getElementById('bt_bootstrap_2.0')
# 			if (!scriptEl) {
# 				const s = document.createElement("script");
# 				el = document.getElementsByTagName("script")[0];
# 				s.setAttribute('id', 'bt_bootstrap_2.0');
# 				s.async = true;
# 				s.src = "//accuweather-com.videoplayerhub.com/btTag.js?w=5760049299324928";
# 				el.parentNode.insertBefore(s, el);
# 			}
# 		};
# 		window.addEventListener('load', callBlockthroughScript);
#
# 			setTimeout(callBlockthroughScript, 15000);
# 				</script>
# <script>
# 		try {
# 		;
# 		} catch (error) { }
# 	</script>
# <popup-banner banner-order="1" class="pushly-prompt-custom" delay="4000" id="pushly-prompt-custom">
# <div class="banner-body">
# <div>
# <p id="pushly-phrase-text">...</p>
# </div>
# <div>
# <button class="pushly-prompt-buttons-allow banner-enable-button" id="pushly-allow-button">
# 				...
# 			</button>
# </div>
# <button class="pushly-prompt-buttons-dismiss banner-dismiss-button" id="pushly-dismiss-button">
# 			...
# 		</button>
# </div>
# </popup-banner>
# <div class="pushly-banner enabled-banner pushly-prompt-custom" id="pushly-enabled-banner" style="display: none">
# <div class="banner-body">
# <p class="title" id="pushly-enabled-title">
# <span class="checkmark-wrapper">
# <check-icon></check-icon>
# </span>
# 			...
# 		</p>
# <p id="pushly-enabled-thanks">...</p>
# </div>
# </div>
# <script>(async () => {(function(){try{var n=window.tagEngineDataLayer||{},r=n.pushly||{};if(!r.isEnabled||!r.pushlyKey){console.warn("[Pushly SDK] Not enabled or missing key");return}var e=document.createElement("script");e.src="https://cdn.p-n.io/pushly-sdk.min.js?domain_key="+encodeURIComponent(r.pushlyKey),e.defer=!0,e.onerror=function(){window.pushlyCallbackError=!0,console.error("[Pushly SDK] Failed to load")},document.head.appendChild(e)}catch(o){console.error("[Pushly SDK] Error loading SDK",o)}})();
# //# sourceMappingURL=pushly-sdk.inline.10-9f45dbaf.js.map
# })();</script><script>(async () => {(function(){const i=window.tagEngineDataLayer?.pushly;if(!i?.isEnabled||!window.PushlySDK)return;const t=i.userLocationKeys||[];window.PushlySDK=window.PushlySDK||[];function o(){window.PushlySDK.push(arguments)}function s(){let e=localStorage.getItem("pushlySettings");if(e){let n=JSON.parse(e);return{daily:n.dailyAlerts?t[0]:null,gov:n.governmentAlerts.length>0?t:[],proximity:n.lightningAlerts.length>0?t:[],news:Object.keys(n.subcategories).filter(l=>n.subcategories[l]),locations:t}}return{daily:t.length>0?t[0]:null,gov:t,proximity:t,news:["airQuality","astronomy","sports","topStories"],locations:t}}o("on_ready",function(){const e=s();o("profile",{daily:e.daily,gov:e.gov,proximity:e.proximity,news:e.news,locations:e.locations})})})();
# //# sourceMappingURL=pushly-profile.inline.15-353836f1.js.map
# })();</script><script>(async () => {(function(){var t=window.__parselyConfig?.site;if(t){var e=document.createElement("script");e.type="text/javascript",e.id="parsely-cfg",e.src="//cdn.parsely.com/keys/"+t+"/p.js",e.defer=!0,document.head.appendChild(e)}})();
# //# sourceMappingURL=parsely.inline.20-70e9af64.js.map
# })();</script><script>(async () => {window.bannerElements=window.bannerElements||[];function o(e){if(e){e.dataset.bannerOrder=null;const t=window.bannerElements.find(n=>n.el===e);t&&(t.order=null)}}function u(){if(window.bannerElements.length>0){const e=window.bannerElements.find(n=>n.isActive);if(e&&v(e))return;e&&(e.isActive=!1);const t=window.bannerElements.filter(n=>n.el.dataset.bannerOrder>=0).sort((n,i)=>n.order-i.order).find(n=>!n.didDisplay);t&&B(t)}}function B(e){if(!e||!e.hasOwnProperty("el")||window.bannerElements.filter(i=>i.isActive).length>0)return;e.didDisplay=!0,e.isActive=!0;let n=0;if(e.el.dataset.bannerDelay){const i=Date.now()-window.__bannerInitialLoad;n=e.el.dataset.bannerDelay-i}n<0&&(n=0),setTimeout(()=>{e.order!==null&&!_()&&(e.el.style.removeProperty?e.el.style.removeProperty("display"):e.el.style.removeAttribute("display"),e.el.visibleCallback&&e.el.visibleCallback())},n)}function _(){return window.bannerElements.map(e=>v(e)).filter(e=>e).length>0}function v(e){const t=document.getElementById(e.id);return t&&window.getComputedStyle(t).display!=="none"}window.__bannerInitialLoad=Date.now();document.querySelectorAll("div[data-banner-order]").forEach(e=>{window.bannerElements.find(t=>t.el===e)||window.bannerElements.push({el:e,order:e.dataset.bannerOrder,didDisplay:!1,isActive:!1,id:e.id})});u();const s=document.getElementById("pushly-prompt-custom"),l=document.getElementById("pushly-enabled-banner"),E=(window.userCookie?.lang||"en").toLowerCase(),r=window.pushlyTranslations?.[E]||window.pushlyTranslations.en,y=document.querySelector(".pushly-prompt-custom .banner-body p"),p=document.querySelector(".pushly-prompt-buttons-allow"),f=document.querySelector(".pushly-prompt-buttons-dismiss"),m=document.querySelector("#pushly-enabled-banner .title"),h=document.querySelector("#pushly-enabled-banner p:last-of-type");y&&(y.textContent=r.phrase);p&&(p.textContent=r.enableNotifications);f&&(f.textContent=r.noThanks);m&&(m.innerText=r.enabled);h&&(h.innerText=r.thanks);let w=!1;function a(e){e&&e.remove(e)}function d(){a(s),a(l),u()}function I(){b(s),b(l),u()}function b(e){e&&(e.style.display="none")}function g(e){e&&(e.style.display="block")}const S=e=>{const t=localStorage.getItem("pushlyStatus");(!t||t!=="subscribed")&&localStorage.setItem("pushlyStatus",e)};function A(e,t=5,n=250,i=1e3){const c=()=>{typeof window.ketch=="function"?setTimeout(e,i):t>0?(t--,setTimeout(c,n)):e()};c()}typeof pushly=="function"&&A(()=>{pushly("on_ready",()=>{w=!0;const e=PushlySDK?.context?.user?.subscriberState;if(["subscribed","blocked","dismissed"].includes(e)&&(S(e),o(s),d()),e==="subscribed"&&localStorage.getItem("pushlySettingsInitialized")!=="true"){const t={dailyAlerts:!0,governmentAlerts:["gov-alerts"],lightningAlerts:["lightning-alerts"],weatherNews:!0,subcategories:{topStories:!0,astronomy:!0,airQuality:!0,sports:!0}};localStorage.setItem("pushlySettings",JSON.stringify(t)),localStorage.setItem("pushlySettingsInitialized","true"),pushly("profile",{daily:t.dailyAlerts?userLocationKeys[0]:null,gov:t.governmentAlerts.length>0?userLocationKeys:[],proximity:t.lightningAlerts.length>0?userLocationKeys:[],news:Object.keys(t.subcategories).filter(n=>t.subcategories[n]),locations:userLocationKeys})}pushly("on_permission_allowed",()=>{if(S("subscribed"),a(s),g(l),localStorage.getItem("pushlySettingsInitialized")!=="true"){const t={dailyAlerts:!0,governmentAlerts:["gov-alerts"],lightningAlerts:["lightning-alerts"],weatherNews:!0,subcategories:{topStories:!0,astronomy:!0,airQuality:!0,sports:!0}};localStorage.setItem("pushlySettings",JSON.stringify(t)),localStorage.setItem("pushlySettingsInitialized","true")}setTimeout(()=>{a(l),u()},2500)}),PushlySDK.context.user.subscriberState!=="subscribed"&&localStorage.setItem("pushly-interests",[])}),["on_permission_denied","on_permission_dismissed","on_prompt_dismissed","on_web_push_unsupported","on_prompt_ineligible"].forEach(e=>{pushly(e,()=>{I()})}),pushly("on_loaded",()=>{location.protoco ...
# //# sourceMappingURL=pushly-banner.inline.25-fd4da8b7.js.map
# })();</script><style>.pushly-prompt-custom{transition:opacity .3s;opacity:0;display:block;visibility:hidden;position:fixed;bottom:12px;width:320px;height:160px;background:#1f1f1fe6;border-radius:8px;z-index:2147483600}@media (width >= 344px){.pushly-prompt-custom{left:9px}}.pushly-prompt-custom.enabled-banner{animation:fadeIn .3s ease-out;animation-fill-mode:forwards;height:94px;text-align:center;opacity:1;visibility:visible}@keyframes fadeIn{0%{opacity:0}to{opacity:1}}.pushly-prompt-custom.enabled-banner .title{margin-bottom:8px;font-weight:700}.pushly-prompt-custom.enabled-banner .title .checkmark-wrapper{margin-right:12px}.pushly-prompt-custom.enabled-banner .title .checkmark-wrapper .icon-check{fill:#343434;background:#fff;border:solid .7px #343434;width:10px;height:10px;border-radius:50%;padding:2px}.pushly-prompt-custom .banner-body{padding:16px;position:relative;height:100%;width:100%;display:block}.pushly-prompt-custom .banner-body p{font-size:16px;color:#fff}.pushly-prompt-custom .banner-body .banner-enable-button{font-size:16px;font-weight:700;color:#000;background:#fff;border-radius:2px;border:none;padding:12px 0;cursor:pointer;width:100%;text-align:center;position:relative;top:16px;margin-bottom:12px}.pushly-prompt-custom .banner-body .banner-enable-button:hover{text-decoration:underline}.pushly-prompt-custom .banner-body .banner-dismiss-button{font-size:14px;color:#fff;cursor:pointer;width:100%;text-align:center;position:relative;top:14px;text-decoration:underline;background:none!important;border:none;padding:0!important}.pushly-prompt-custom.pushly-web-push-supported{visibility:visible;opacity:1}.pushly-prompt-custom.pushly-subscription-dismissed{display:none}@keyframes fadeInPushly{0%{opacity:0;visibility:hidden}to{opacity:1;visibility:visible}}.pushly-prompt-custom.pushly-fade-in{animation:fadeInPushly .3s ease-out forwards}@media (width >= 1024px){body.new-ui .pushly-prompt-custom{left:92px}}
# </style>
# <script>(async () => {(function(){function m(n,e){const c="https://sb.scorecardresearch.com/p?",t=Array.from(document.querySelectorAll('img[src^="'+c+'"]'));if(t.find(s=>s.src.includes(`cs_ucfr=${n}`)))return;const o=t.find(s=>s.src.includes("cs_ucfr=")&&!s.src.includes(`cs_ucfr=${n}`));o&&o.remove();const d=`${c}cs_fpid=${e.cs_fpid}&cs_fpit=c&c1=2&c2=6005068&c4=${encodeURIComponent(e.c4)}&c7=${encodeURIComponent(e.c7)}&c8=${encodeURIComponent(e.c8)}&c9=${encodeURIComponent(e.c9)}&cs_ucfr=${n}`,i=document.createElement("img");i.src=d,i.alt="ComScore",i.style.display="none",document.body.appendChild(i)}function a(){const n=window.tagEngineDataLayer?.comScore;if(!n)return;const e=100,c=2e3;let t=0;const r=()=>{typeof window.ketch=="function"?window.ketch("on","consent",function(o){const d=o?.purposes?.targeted_advertising;m(d===!0?1:0,n)}):t<c&&(t+=e,setTimeout(r,e))};r()}document.readyState==="complete"||document.readyState==="interactive"?a():document.addEventListener("DOMContentLoaded",a)})();
# //# sourceMappingURL=comscore.inline.5-abc6ca40.js.map
# })();</script><script>(async () => {(function(){const a=window.tagEngineDataLayer?.connatix;if(!a||!a.isActive)return;const{adUnitCode:i,cacheBuster:d,ppid:p,gdprConsent:n,adInfo:r,thirdPartyCookie:m}=a,e=new URL("https://securepubads.g.doubleclick.net/gampad/adx");if(e.searchParams.set("iu",i),e.searchParams.set("sz","3x3"),e.searchParams.set("c",d),e.searchParams.set("m","text/javascript"),e.searchParams.set("ppid",p),e.searchParams.set("userid3p",m||h()),r&&typeof r=="object"){const t=Object.entries(r).map(([o,s])=>`${o}=${s}`).join("&");t&&e.searchParams.set("t",encodeURIComponent(t))}n&&(e.searchParams.set("gdpr","1"),e.searchParams.set("gdpr_consent",n));const c=document.createElement("script");c.src=e.toString(),c.async=!0,document.head.appendChild(c);function h(){const t="userid3p",s=document.cookie.split("; ").find(u=>u.startsWith(t+"="));return s?s.split("=")[1]:""}})();
# //# sourceMappingURL=connatix.inline.25-2d9ce886.js.map
# })();</script>
# <noscript><img src="https://www.accuweather.com/akam/13/pixel_5a3556d4?a=dD1lY2U2MzJhYzBmNzhkM2FjNDc5MDZiYmFiNDRlOGE2OGFhOWQ4ZTQxJmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;"/></noscript></body>
# </html>

# %%
weather_data = []
for tag in soup.find_all(['h1', 'h2', 'h3', 'p']):
    text = tag.get_text(" ", strip=True)
    weather_data.append(text)

# combine all elements into a single string
weather_data = "\n".join(weather_data)

# remove all spaces from the combined text
weather_data = re.sub(r'\s+', ' ', weather_data)

print(f"Website: {url}\n\n")
print(weather_data)
# Out:
# Website: https://www.accuweather.com/en/pk/lahore/260622/current-weather/260622
#
#
# Lahore, Punjab Lahore Punjab Around the Globe Around the Globe Hurricane Tracker Radar & Maps News & Features Astronomy Business Climate Health Recreation Sports Travel Warnings Data Suite Newsletters Advertising Superior Accuracy™ Video Current Weather 12:10 PM Day Max UV Index 12 (Extreme) AccuLumen Brightness Index™ 7 (Bright) Wind E 17 km/h Wind Gusts 30 km/h Probability of Precipitation 5% Probability of Thunderstorms 1% Precipitation 0.0 mm Cloud Cover 53% Morning Afternoon Night Wind ESE 13 km/h Wind Gusts 19 km/h Probability of Precipitation 3% Probability of Thunderstorms 1% Precipitation 0.0 mm Cloud Cover 0% Evening Overnight Sun & Moon Temperature History Further Ahead Further Ahead Hourly Daily Monthly Around the Globe Around the Globe Hurricane Tracker Radar & Maps News Video Top Stories Weather News Deadly West Virginia flooding won't be the last of this week 11 hours ago Severe Weather Rounds of severe storms to continue in central and eastern US 12 hours ago Recreation Tourist falls trying to view Kilauea eruption 15 hours ago Weather Forecasts More stormy downpours for northeast US, but heatwave is on horizon 13 hours ago Astronomy Will the Aurora Borealis be visible this week? 14 hours ago Featured Stories Recreation Northern US states try to woo travelers with ‘Canadians-only’ deals 13 hours ago Astronomy Summer solstice: Everything to know about the year's longest day 1 week ago Weather News 5 times the American flag survived extreme weather 14 hours ago Weather News Reopening a 688-year-old murder case 17 hours ago Weather News 6,000-year-old skeletons found in Colombia have unique DNA 17 hours ago Weather Near Lahore: ... ... ...

# %%
#Now let's use agentic search tool
result = client.search(query, max_results=1)

#print first result
data = result["results"][0]["content"]

print(data)
# Out:
# {'location': {'name': 'Lahore', 'region': 'Punjab', 'country': 'Pakistan', 'lat': 31.5497, 'lon': 74.3436, 'tz_id': 'Asia/Karachi', 'localtime_epoch': 1750144827, 'localtime': '2025-06-17 12:20'}, 'current': {'last_updated_epoch': 1750144500, 'last_updated': '2025-06-17 12:15', 'temp_c': 30.1, 'temp_f': 86.2, 'is_day': 1, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 8.5, 'wind_kph': 13.7, 'wind_degree': 118, 'wind_dir': 'ESE', 'pressure_mb': 1002.0, 'pressure_in': 29.59, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 66, 'cloud': 75, 'feelslike_c': 29.2, 'feelslike_f': 84.6, 'windchill_c': 38.9, 'windchill_f': 101.9, 'heatindex_c': 42.5, 'heatindex_f': 108.6, 'dewpoint_c': 19.1, 'dewpoint_f': 66.5, 'vis_km': 6.0, 'vis_miles': 3.0, 'uv': 7.8, 'gust_mph': 9.8, 'gust_kph': 15.7}}

# %%
import json
from pygments import highlight, lexers, formatters

#parse JSON
parsed_json = json.loads(data.replace("'", '"'))

#pretty print Json with syntax highlighting
formatted_json = json.dumps(parsed_json, indent=4)
colorful_json = highlight(formatted_json,
                          lexers.JsonLexer(),
                          formatters.TerminalFormatter())
print(colorful_json)
# Out:
# {
#     "location": {
#         "name": "Lahore",
#         "region": "Punjab",
#         "country": "Pakistan",
#         "lat": 31.5497,
#         "lon": 74.3436,
#         "tz_id": "Asia/Karachi",
#         "localtime_epoch": 1750144827,
#         "localtime": "2025-06-17 12:20"
#     },
#     "current": {
#         "last_updated_epoch": 1750144500,
#         "last_updated": "2025-06-17 12:15",
#         "temp_c": 30.1,
#         "temp_f": 86.2,
#         "is_day": 1,
#         "condition": {
#             "text": "Partly cloudy",
#             "icon": "//cdn.weatherapi.com/weather/64x64/day/116.png",
#             "code": 1003
#         },
#         "wind_mph": 8.5,
#         "wind_kph": 13.7,
#         "wind_degree": 118,
#         "wind_dir": "ESE",
#         "pressure_mb": 1002.0,
#         "pressure_in": 29.59,
#         "precip_mm": 0.0,
#         "precip_in": 0.0,
#         "humidity": 66,
#         "cloud": 75,
#         "feelslike_c": 29.2,
#         "feelslike_f": 84.6,
#         "windchill_c": 38.9,
#         "windchill_f": 101.9,
#         "heatindex_c": 42.5,
#         "heatindex_f": 108.6,
#         "dewpoint_c": 19.1,
#         "dewpoint_f": 66.5,
#         "vis_km": 6.0,
#         "vis_miles": 3.0,
#         "uv": 7.8,
#         "gust_mph": 9.8,
#         "gust_kph": 15.7
#     }
# }
